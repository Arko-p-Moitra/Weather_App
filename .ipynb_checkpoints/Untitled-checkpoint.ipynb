# %%
#This is an API program for weather API
import requests
from pytz import timezone
from datetime import datetime
from pprint import pprint
#city = input('Enter your City = ')
#This URL is our APi end point
url='http://api.openweathermap.org/data/2.5/forecast?q=delhi&appid=417ecd9eea84ffc6f0b4093c255446e2&units=metric'
#url='http://api.openweathermap.org/data/2.5/weather?q=jalpaiguri&appid=417ecd9eea84ffc6f0b4093c255446e2&units=metric'
res= requests.get(url)
data= res.json() 
#pprint(data)
#print(type(data))
pprint(data['list'][])
print(len(data['list'][1]))
#pprint(data['list'][0]['dt'])
#print(data['list'][0]['main']['temp'])
# Out:
# {'clouds': {'all': 12},
#  'dt': 1591596000,
#  'dt_txt': '2020-06-08 06:00:00',
#  'main': {'feels_like': 38.59,
#           'grnd_level': 976,
#           'humidity': 25,
#           'pressure': 1000,
#           'sea_level': 1000,
#           'temp': 39.47,
#           'temp_kf': 0,
#           'temp_max': 39.47,
#           'temp_min': 39.47},
#  'sys': {'pod': 'd'},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 283, 'speed': 3.96}}
# 8

# %%
tempa=data['main']['temp']
hum=data['main']['humidity']
windSpeed=data['wind']['speed']
dat=(data['weather'])

print(dat[0])
#print(dat['description'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-08b1b4ba13cb> in <module>
#       4 dat=(data['weather'])
#       5
# ----> 6 print({dat[0]})
#       7 #print(dat['description'])
#
# TypeError: unhashable type: 'dict'

# %%
#This is an API program for weather API
import requests
from pytz import timezone
from datetime import datetime
from pprint import pprint
#city = input('Enter your City = ')
#This URL is our APi end point
url='http://api.openweathermap.org/data/2.5/forecast?q=delhi&appid=417ecd9eea84ffc6f0b4093c255446e2&units=metric'#.format(city)
#url='http://api.openweathermap.org/data/2.5/weather?q=gujrat&appid=417ecd9eea84ffc6f0b4093c255446e2&units=metric'
res= requests.get(url)
data= res.json() 
#print(res)
pprint(data)
# Out:
# {'city': {'coord': {'lat': 28.6667, 'lon': 77.2167},
#           'country': 'IN',
#           'id': 1273294,
#           'name': 'Delhi',
#           'population': 10927986,
#           'sunrise': 1590969221,
#           'sunset': 1591019078,
#           'timezone': 19800},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 25},
#            'dt': 1591034400,
#            'dt_txt': '2020-06-01 18:00:00',
#            'main': {'feels_like': 34.14,
#                     'grnd_level': 980,
#                     'humidity': 43,
#                     'pressure': 1006,
#                     'sea_level': 1004,
#                     'temp': 31.91,
#                     'temp_kf': -1.44,
#                     'temp_max': 33.35,
#                     'temp_min': 31.91},
#            'rain': {'3h': 0.77},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
# ...
